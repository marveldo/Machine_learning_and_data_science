# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('PastHires.csv')

# %%
name = np.random.normal(0.8,0.6,50)

# %%
df
# Out:
#     Years Experience Employed?  Previous employers Level of Education  \
# 0                 10         Y                   4                 BS
# 1                  0         N                   0                 BS
# 2                  7         N                   6                 BS
# 3                  2         Y                   1                 MS
# 4                 20         N                   2                PhD
# 5                  0         N                   0                PhD
# 6                  5         Y                   2                 MS
# 7                  3         N                   1                 BS
# 8                 15         Y                   5                 BS
# 9                  0         N                   0                 BS
# 10                 1         N                   1                PhD
# 11                 4         Y                   1                 BS
# ...

# %%
df.head()
# Out:
#    Years Experience Employed?  Previous employers Level of Education  \
# 0                10         Y                   4                 BS
# 1                 0         N                   0                 BS
# 2                 7         N                   6                 BS
# 3                 2         Y                   1                 MS
# 4                20         N                   2                PhD
#
#   Top-tier school Interned Hired
# 0               N        N     Y
# 1               Y        Y     Y
# 2               N        N     N
# 3               Y        N     Y
# 4               Y        N     N

# %%
df.tail()
# Out:
#     Years Experience Employed?  Previous employers Level of Education  \
# 8                 15         Y                   5                 BS
# 9                  0         N                   0                 BS
# 10                 1         N                   1                PhD
# 11                 4         Y                   1                 BS
# 12                 0         N                   0                PhD
#
#    Top-tier school Interned Hired
# 8                N        N     Y
# 9                N        N     N
# 10               Y        N     N
# 11               N        Y     Y
# 12               Y        N     Y

# %%
hired = df['Hired']

# %%
hired
# Out:
# 0     Y
# 1     Y
# 2     N
# 3     Y
# 4     N
# 5     Y
# 6     Y
# 7     Y
# 8     Y
# 9     N
# 10    N
# 11    Y
# 12    Y
# Name: Hired, dtype: object

# %%
hired = df['Hired']

# %%
df = df.drop('Hired',axis=1)

# %%
df.head(5)
# Out:
#    Years Experience Employed?  Previous employers Level of Education  \
# 0                10         Y                   4                 BS
# 1                 0         N                   0                 BS
# 2                 7         N                   6                 BS
# 3                 2         Y                   1                 MS
# 4                20         N                   2                PhD
#
#   Top-tier school Interned
# 0               N        N
# 1               Y        Y
# 2               N        N
# 3               Y        N
# 4               Y        N
